# %%
import pandas as pd

# %%
db = pd.read_csv(r'/content/Your Exam-Eve Check-In (Responses).csv')

# %%
db
# Out:
#                Timestamp                  Email Address Q0. Your Gender?  \
# 0    11/12/2025 17:02:02     deepthitanniru19@gmail.com           Female
# 1    11/12/2025 17:04:45        shaikruhi2005@gmail.com           Female
# 2    11/12/2025 17:04:46       pbhanupriya317@gmail.com           Female
# 3    11/12/2025 17:07:10    kurellarachanasri@gmail.com           Female
# 4    11/12/2025 17:08:43         deepaswi2004@gmail.com           Female
# ..                   ...                            ...              ...
# 132  11/20/2025 20:27:41            kuma69375@gmail.com           Female
# 133  11/20/2025 21:13:03        eppajayaraj88@gmail.com             Male
# 134  11/20/2025 21:35:23   sanjayreddyelala85@gmail.com             Male
# 135  11/20/2025 22:15:18         asmikanamala@gmail.com           Female
# 136  11/21/2025 11:39:17  sreekanthpyatagouda@gmail.com             Male
#
#     Q1. Describe your state of mind at time at time of Examination in brief.  \
# ...

# %%
rename = {
    'Timestamp': 'timestamp',
    'Email Address': 'email_address',
    'Q0. Your Gender?': 'gender',
    'Q1. Describe your state of mind at time at time of Examination in brief.': 'state_of_mind',
    'Q2. Before this exam period, how many hours of sleep did you typically get on a normal night?': 'sleep_normal_hours',
    'Q3. And how many hours of sleep did you get last night?': 'sleep_last_night_hours',
    'Q4. About how many total hours did you spend actively studying or reviewing today?': 'study_total_hours',
    'Q5. Which of these best describes the intensity of your study session(s) today?': 'study_intensity',
    'Q6. (Optional) Let\'s try to break down that study time... Hours spent reviewing notes or reading:': 'time_reviewing_notes',
    'Q7. (Optional) Hours spent on assignments, practice problems, or projects:': 'time_assignments_projects',
    'Q8. Time on Social Media (TikTok, Insta, etc.)': 'time_social_media',
    'Q9. Time on Video (Netflix, YouTube, etc.)': 'time_video_streaming',
    'Q10. Time Gaming': 'time_gaming',
    'Q11. Time Socializing (friends, family, in-person/call)': 'time_socializing',
    'Q12. Time on Active/Restorative breaks (exercise, walk, nap, meditation)': 'time_active_breaks',
    'Q13. What percentage of the exam material do you feel you\'ve realistically covered?': 'material_covered_percent',
    'Q14. How confident are you about the most difficult topics you expect on the exam?': 'confidence_difficult_topics',
    'Q15. On a scale of 0 (fresh as a daisy) to 10 (total zombie), how mentally fatigued do you feel right now?': 'fatigue_level',
    'Q16. How overwhelmed by the exam material do you feel right now?': 'overwhelmed_level',
    'Q17. How anxious or "on-edge" do you feel specifically about this exam?': 'anxiety_level',
    'Q18. All things considered, how ready do you feel for tomorrow\'s exam?': 'readiness_level',
    'Q19. If you have a class before your exam tomorrow, how likely are you to actually go?': 'class_attendance_likelihood'
}
db = db.rename(columns=rename)

# %%
db
# Out:
#                timestamp                  email_address  gender  \
# 0    11/12/2025 17:02:02     deepthitanniru19@gmail.com  Female
# 1    11/12/2025 17:04:45        shaikruhi2005@gmail.com  Female
# 2    11/12/2025 17:04:46       pbhanupriya317@gmail.com  Female
# 3    11/12/2025 17:07:10    kurellarachanasri@gmail.com  Female
# 4    11/12/2025 17:08:43         deepaswi2004@gmail.com  Female
# ..                   ...                            ...     ...
# 132  11/20/2025 20:27:41            kuma69375@gmail.com  Female
# 133  11/20/2025 21:13:03        eppajayaraj88@gmail.com    Male
# 134  11/20/2025 21:35:23   sanjayreddyelala85@gmail.com    Male
# 135  11/20/2025 22:15:18         asmikanamala@gmail.com  Female
# 136  11/21/2025 11:39:17  sreekanthpyatagouda@gmail.com    Male
#
#                                          state_of_mind  sleep_normal_hours  \
# 0    At the time of the examination, my mind was a ...                 5.0
# ...

# %%
db['study_intensity'] = db['study_intensity'].astype(str).str.extract(r'(\d+)').astype(int)

# %%
db
# Out:
#                timestamp                  email_address  gender  \
# 0    11/12/2025 17:02:02     deepthitanniru19@gmail.com  Female
# 1    11/12/2025 17:04:45        shaikruhi2005@gmail.com  Female
# 2    11/12/2025 17:04:46       pbhanupriya317@gmail.com  Female
# 3    11/12/2025 17:07:10    kurellarachanasri@gmail.com  Female
# 4    11/12/2025 17:08:43         deepaswi2004@gmail.com  Female
# ..                   ...                            ...     ...
# 132  11/20/2025 20:27:41            kuma69375@gmail.com  Female
# 133  11/20/2025 21:13:03        eppajayaraj88@gmail.com    Male
# 134  11/20/2025 21:35:23   sanjayreddyelala85@gmail.com    Male
# 135  11/20/2025 22:15:18         asmikanamala@gmail.com  Female
# 136  11/21/2025 11:39:17  sreekanthpyatagouda@gmail.com    Male
#
#                                          state_of_mind  sleep_normal_hours  \
# 0    At the time of the examination, my mind was a ...                 5.0
# ...

# %%
db.isna().sum()
# Out:
# timestamp                       0
# email_address                   0
# gender                          0
# state_of_mind                   0
# sleep_normal_hours              0
# sleep_last_night_hours          0
# study_total_hours               0
# study_intensity                 0
# time_reviewing_notes           74
# time_assignments_projects      70
# time_social_media               8
# time_video_streaming            9
# time_gaming                    10
# time_socializing                8
# time_active_breaks              9
# material_covered_percent        0
# confidence_difficult_topics     0
# fatigue_level                   0
# overwhelmed_level               0
# anxiety_level                   0
# readiness_level                 0
# class_attendance_likelihood     0
# dtype: int64

# %%
db['time_reviewing_notes'] = db['time_reviewing_notes'].fillna(0)

# %%
db
# Out:
#                timestamp                  email_address  gender  \
# 0    11/12/2025 17:02:02     deepthitanniru19@gmail.com  Female
# 1    11/12/2025 17:04:45        shaikruhi2005@gmail.com  Female
# 2    11/12/2025 17:04:46       pbhanupriya317@gmail.com  Female
# 3    11/12/2025 17:07:10    kurellarachanasri@gmail.com  Female
# 4    11/12/2025 17:08:43         deepaswi2004@gmail.com  Female
# ..                   ...                            ...     ...
# 132  11/20/2025 20:27:41            kuma69375@gmail.com  Female
# 133  11/20/2025 21:13:03        eppajayaraj88@gmail.com    Male
# 134  11/20/2025 21:35:23   sanjayreddyelala85@gmail.com    Male
# 135  11/20/2025 22:15:18         asmikanamala@gmail.com  Female
# 136  11/21/2025 11:39:17  sreekanthpyatagouda@gmail.com    Male
#
#                                          state_of_mind  sleep_normal_hours  \
# 0    At the time of the examination, my mind was a ...                 5.0
# ...

# %%
db['study_intensity'].unique()
# Out:
# array([3, 4, 1, 2, 5])

# %%
db['time_assignments_projects'] = db['time_assignments_projects'].fillna(0)

# %%
db
# Out:
#                timestamp                  email_address  gender  \
# 0    11/12/2025 17:02:02     deepthitanniru19@gmail.com  Female
# 1    11/12/2025 17:04:45        shaikruhi2005@gmail.com  Female
# 2    11/12/2025 17:04:46       pbhanupriya317@gmail.com  Female
# 3    11/12/2025 17:07:10    kurellarachanasri@gmail.com  Female
# 4    11/12/2025 17:08:43         deepaswi2004@gmail.com  Female
# ..                   ...                            ...     ...
# 132  11/20/2025 20:27:41            kuma69375@gmail.com  Female
# 133  11/20/2025 21:13:03        eppajayaraj88@gmail.com    Male
# 134  11/20/2025 21:35:23   sanjayreddyelala85@gmail.com    Male
# 135  11/20/2025 22:15:18         asmikanamala@gmail.com  Female
# 136  11/21/2025 11:39:17  sreekanthpyatagouda@gmail.com    Male
#
#                                          state_of_mind  sleep_normal_hours  \
# 0    At the time of the examination, my mind was a ...                 5.0
# ...

# %%
db.isna().sum()
# Out:
# timestamp                       0
# email_address                   0
# gender                          0
# state_of_mind                   0
# sleep_normal_hours              0
# sleep_last_night_hours          0
# study_total_hours               0
# study_intensity                 0
# time_reviewing_notes            0
# time_assignments_projects       0
# time_social_media               8
# time_video_streaming            9
# time_gaming                    10
# time_socializing                8
# time_active_breaks              9
# material_covered_percent        0
# confidence_difficult_topics     0
# fatigue_level                   0
# overwhelmed_level               0
# anxiety_level                   0
# readiness_level                 0
# class_attendance_likelihood     0
# dtype: int64

# %%
db['time_social_media'].median()
# Out:
# 2.0

# %%
db['time_social_media'] = db['time_social_media'].fillna(0)

# %%
db['time_social_media'].dtype
# Out:
# dtype('float64')

# %%
db['time_video_streaming'].median()
# Out:
# 1.0

# %%
db['time_gaming'].median()
# Out:
# 0.0

# %%
db['time_gaming'].mode()
# Out:
# 0    0.0
# Name: time_gaming, dtype: float64

# %%
db['time_video_streaming'] = db['time_video_streaming'].fillna(0)

# %%
db['time_gaming'] = db['time_gaming'].fillna(0)

# %%
db['time_socializing'] = db['time_socializing'].fillna(0)

# %%
db['time_active_breaks'] = db['time_active_breaks'].fillna(0)

# %%
db.isna().sum()
# Out:
# timestamp                      0
# email_address                  0
# gender                         0
# state_of_mind                  0
# sleep_normal_hours             0
# sleep_last_night_hours         0
# study_total_hours              0
# study_intensity                0
# time_reviewing_notes           0
# time_assignments_projects      0
# time_social_media              0
# time_video_streaming           0
# time_gaming                    0
# time_socializing               0
# time_active_breaks             0
# material_covered_percent       0
# confidence_difficult_topics    0
# fatigue_level                  0
# overwhelmed_level              0
# anxiety_level                  0
# readiness_level                0
# class_attendance_likelihood    0
# dtype: int64

# %%
db['material_covered_percent'].dtype
# Out:
# dtype('O')

# %%
db['material_covered_percent'] = db['material_covered_percent'].astype(str).str.extract(r'(\d+)').astype(int)

# %%
db['material_covered_percent']
# Out:
# 0      80
# 1      80
# 2      80
# 3      90
# 4      90
#        ..
# 132    50
# 133     0
# 134    80
# 135    40
# 136    60
# Name: material_covered_percent, Length: 137, dtype: int64

# %%
db['confidence_difficult_topics'] = db['confidence_difficult_topics'].astype(str).str.extract(r'(\d+)').astype(int)

# %%
db['confidence_difficult_topics']
# Out:
# 0      4
# 1      2
# 2      3
# 3      5
# 4      4
#       ..
# 132    5
# 133    1
# 134    4
# 135    3
# 136    1
# Name: confidence_difficult_topics, Length: 137, dtype: int64

# %%
db['readiness_level'].unique()
# Out:
# array(['Somewhat ready (Medium)', 'Very ready (High)',
#        'Not at all ready (Low)'], dtype=object)

# %%
db['readiness_level'] = db['readiness_level'].replace({
    'Somewhat ready (Medium)': 'Medium',
    'Very ready (High)': 'High',
    'Not at all ready (Low)': 'Low'
})

# %%
db['readiness_level']
# Out:
# 0      Medium
# 1      Medium
# 2      Medium
# 3      Medium
# 4        High
#         ...
# 132       Low
# 133       Low
# 134       Low
# 135    Medium
# 136    Medium
# Name: readiness_level, Length: 137, dtype: object

# %%
db['class_attendance_likelihood'].unique()
# Out:
# array(['Definitely going', 'Not sure yet', 'Probably skipping',
#        "I don't have one"], dtype=object)

# %%
db.duplicated().sum()
# Out:
# np.int64(0)

# %%
db
# Out:
#                timestamp                  email_address  gender  \
# 0    11/12/2025 17:02:02     deepthitanniru19@gmail.com  Female
# 1    11/12/2025 17:04:45        shaikruhi2005@gmail.com  Female
# 2    11/12/2025 17:04:46       pbhanupriya317@gmail.com  Female
# 3    11/12/2025 17:07:10    kurellarachanasri@gmail.com  Female
# 4    11/12/2025 17:08:43         deepaswi2004@gmail.com  Female
# ..                   ...                            ...     ...
# 132  11/20/2025 20:27:41            kuma69375@gmail.com  Female
# 133  11/20/2025 21:13:03        eppajayaraj88@gmail.com    Male
# 134  11/20/2025 21:35:23   sanjayreddyelala85@gmail.com    Male
# 135  11/20/2025 22:15:18         asmikanamala@gmail.com  Female
# 136  11/21/2025 11:39:17  sreekanthpyatagouda@gmail.com    Male
#
#                                          state_of_mind  sleep_normal_hours  \
# 0    At the time of the examination, my mind was a ...                 5.0
# ...

# %%
x = db[['gender', 'study_intensity', 'time_social_media', 'time_gaming', 'time_socializing', 'time_active_breaks', 'material_covered_percent',
        'confidence_difficult_topics', 'fatigue_level', 'overwhelmed_level', 'anxiety_level']]

# %%
x
# Out:
#      gender  study_intensity  time_social_media  time_gaming  \
# 0    Female                3                0.0          0.0
# 1    Female                4                0.0          1.0
# 2    Female                4                1.0          0.0
# 3    Female                1                2.0          0.0
# 4    Female                3                0.0          0.5
# ..      ...              ...                ...          ...
# 132  Female                2                2.0          0.0
# 133    Male                1                5.5          0.5
# 134    Male                1                6.0          1.0
# 135  Female                2                0.0          0.0
# 136    Male                3                1.0          0.0
#
#      time_socializing  time_active_breaks  material_covered_percent  \
# 0                 0.0                 0.0                        80
# 1                 0.5                 0.5                        80
# ...

# %%
y = db['readiness_level']

# %%
xcont = db[['time_social_media', 'time_gaming', 'time_socializing', 'time_active_breaks', 'material_covered_percent']]

# %%
xcat = db[['gender', 'study_intensity', 'confidence_difficult_topics', 'fatigue_level', 'overwhelmed_level', 'anxiety_level']]

# %%
from sklearn.model_selection import train_test_split

# %%
xCatTrain, xCatTest, xContTrain, xContTest,  yTrain, yTest = train_test_split(xcat,xcont,y,test_size=0.2,
                                                train_size=0.8,
                                                random_state=23,
                                                stratify=y)

# %%
from sklearn.preprocessing import PowerTransformer

# %%
yjt = PowerTransformer()

# %%
xContTrain.columns
# Out:
# Index(['time_social_media', 'time_gaming', 'time_socializing',
#        'time_active_breaks', 'material_covered_percent'],
#       dtype='object')

# %%
xContTrainGuassian = yjt.fit_transform(xContTrain)

# %%
xContTestGuassian = yjt.transform(xContTest)

# %%
xContTestGuassian = pd.DataFrame(xContTestGuassian, columns=yjt.get_feature_names_out())

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

# %%
xCatOheTrain = ohe.fit_transform(xCatTrain)

# %%
xCatOheTest = ohe.transform(xCatTest)

# %%
xCatOheTest = pd.DataFrame(xCatOheTest.todense(), columns=ohe.get_feature_names_out())

# %%
xTest = pd.concat((xContTestGuassian, xCatOheTest), axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
yTrain_encoded = le.fit_transform(yTrain)

# %%
yTest_encoded = le.transform(yTest)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
xohepd = pd.DataFrame(xCatOheTrain.todense(), columns=ohe.get_feature_names_out())

# %%
xContTrainGaussian=pd.DataFrame(xContTrainGuassian, columns=yjt.get_feature_names_out())

# %%
xtrain = pd.concat((xContTrainGaussian, xohepd), axis=1)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain, yTrain_encoded)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(xTest)

# %%
y_pred
# Out:
# array([2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2,
#        2, 2, 2, 2, 2, 0])

# %%
accuracy_score(yTest_encoded, y_pred)
# Out:
# 0.6071428571428571

# %%
confusion_matrix(yTest_encoded, y_pred)
# Out:
# array([[ 0,  1,  5],
#        [ 0,  0,  3],
#        [ 2,  0, 17]])

# %%
y_pred_train = knn.predict(xtrain)
accuracy_score(yTrain_encoded, y_pred_train)
# Out:
# 0.7064220183486238

# %% [markdown]
# some what high accuracy in train than test that means my model is mild overfitting

# %%
import pandas as pd
import scipy.stats as stats
table = pd.crosstab(db['gender'], db['study_intensity'])

# Run Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(table)

print("Chi-square statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-square statistic: 7.598277582130558
# p-value: 0.10745293859532039

# %%
table
# Out:
# study_intensity   1   2   3  4  5
# gender
# Female            5  13  30  6  3
# Male             10  33  25  8  4

# %%
expected
# Out:
# array([[ 6.24087591, 19.13868613, 22.88321168,  5.82481752,  2.91240876],
#        [ 8.75912409, 26.86131387, 32.11678832,  8.17518248,  4.08759124]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=db, x='gender', hue='study_intensity')
plt.title("Gender vs Study Intensity")
plt.show()

# %%
sns.countplot(data=db, x='gender', hue='readiness_level')
plt.title("Gender vs Readyness Level")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(14, 8))
ax1.set_title("students spending time on social media")
sns.barplot(data=db, x='gender', y='time_social_media', ax=ax1)
ax2.set_title("students spending time on gaming")
sns.barplot(data=db, x='gender', y='time_gaming', ax=ax2)
ax3.set_title("students spending time on socializing")
sns.barplot(data=db, x='gender', y='time_socializing', ax=ax3)
ax4.set_title("students taking active breaks in hours")
sns.barplot(data=db, x='gender', y='time_active_breaks', ax=ax4)

plt.tight_layout()
plt.show()

# %%
from scipy import stats
import numpy as np

# %%
table = pd.crosstab(db['gender'], db['readiness_level'])

# Run Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(table)

print("Chi-square statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-square statistic: 1.7275319555841782
# p-value: 0.4215714603167794

# %%
table
# Out:
# readiness_level  High  Low  Medium
# gender
# Female              9    7      41
# Male               20    8      52

# %%
expected
# Out:
# array([[12.06569343,  6.24087591, 38.69343066],
#        [16.93430657,  8.75912409, 54.30656934]])

# %%
db['study_intensity'].unique()
# Out:
# array([3, 4, 1, 2, 5])

# %%
table = pd.crosstab(db['study_intensity'], db['readiness_level'])

# Run Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(table)

print("Chi-square statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-square statistic: 6.959295782914296
# p-value: 0.5410306730499489

# %%
if p < 0.05:
  print('Reject the null hypothesis')
else:
  print('Fail to reject the null hypothesis')
# Out:
# Fail to reject the null hypothesis

# %%
table
# Out:
# readiness_level  High  Low  Medium
# study_intensity
# 1                   2    3      10
# 2                   8    5      33
# 3                  14    3      38
# 4                   3    2       9
# 5                   2    2       3

# %%
expected
# Out:
# array([[ 3.17518248,  1.64233577, 10.18248175],
#        [ 9.73722628,  5.03649635, 31.22627737],
#        [11.64233577,  6.02189781, 37.33576642],
#        [ 2.96350365,  1.53284672,  9.50364964],
#        [ 1.48175182,  0.76642336,  4.75182482]])

# %%
readiness_timebreak = [db[db['readiness_level'] == dept]['time_active_breaks']
                 for dept in db['readiness_level'].unique()]

# %%
readiness_timebreak
# Out:
# [0      0.0
#  1      0.5
#  2      1.5
#  3      0.0
#  6      0.0
#        ...
#  128    1.0
#  130    2.0
#  131    2.0
#  135    2.0
#  136    2.0
#  Name: time_active_breaks, Length: 93, dtype: float64,
#  4      1.0
#  9      2.0
#  10     1.0
#  12     1.0
#  16     4.0
#  20     2.0
#  22     1.0
#  24     0.5
#  26     0.0
#  27     0.0
#  49     2.0
#  52     1.0
#  55     0.0
#  57     1.5
#  68     2.5
#  77     1.0
#  79     1.0
#  82     0.0
#  84     1.0
#  86     2.0
#  87     1.0
#  93     2.0
#  96     0.5
#  98     1.0
#  102    1.0
#  105    2.0
#  117    1.0
#  120    2.0
#  129    2.0
#  Name: time_active_breaks, dtype: float64,
#  5      1.0
#  28     1.0
#  33     1.5
#  45     2.0
#  47     2.0
#  56     3.0
#  62     1.0
#  81     1.0
#  83     0.0
#  103    0.0
#  104    0.5
#  125    0.5
#  132    0.0
#  133    0.5
#  134    0.5
#  Name: time_active_breaks, dtype: float64]

# %%
db['readiness_level'].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
from scipy.stats import f_oneway

# %%
f_stat, p_val = f_oneway(*readiness_timebreak)

# %%
f_stat, p_val
# Out:
# (np.float64(0.8667223518155454), np.float64(0.42266972056068774))

# %%
if p_val < 0.05:
  print('Reject the null hypothesis')
else:
  print('Fail to reject the null hypothesis')
# Out:
# Fail to reject the null hypothesis
